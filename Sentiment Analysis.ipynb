# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.corpus import stopwords

# %%
review = pd.read_csv("yelp_dataset/review.json.csv")
review
# Out:
#                       review_id                 user_id  \
# 0        Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA
# 1        GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg
# 2        2TzJjDVDEuAW6MR5Vuc1ug  n6-Gk65cPZL6Uz8qRm3NYw
# 3        yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg
# 4        11a8sVPMUFtaC7_ABRkmtw  ssoyf2_x0EQMed6fgHeMyQ
# 5        fdiNeiN_hoCxCMy2wTRW9g  w31MKYsNFMrjhWxxAb5wIw
# 6        G7XHMxG0bx9oBJNECG4IFg  jlu4CztcSxrKx56ba1a5AQ
# 7        8e9HxxLjjqc9ez5ezzN7iQ  d6xvYpyzcfbF_AZ8vMB7QA
# 8        qrffudO73zsslZbe8B9D3Q  sG_h0dIzTKWa3Q6fmb4u-g
# 9        RS_GTIT6836bCaPy637kNQ  nMeCE5-xsdleyxYuNZ_7rA
# 10       kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA
# 11       -I5umRTkhw15RqpKMl_o1Q  -mA3-1mN4JIEkqOtdbNXCQ
# 12       Z7wgXp98wYB57QdRY3HQ3w  GYNnVehQeXjty0xH7-6Fhw
# 13       qlXw1JQ0UodW7qrmVgwCXw  bAhqAPoWaZYcyYi7bs024Q
# 14       JVcjMhlavKKn3UIt9p9OXA  TpyOT5E16YASd7EWjLQlrw
# 15       svK3nBU7Rk8VfGorlrN52A  NJlxGtouq06hhC7sS2ECYw
# ...

# %%
review.shape
# Out:
# (6685900, 9)

# %%
review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
# 2  2TzJjDVDEuAW6MR5Vuc1ug  n6-Gk65cPZL6Uz8qRm3NYw  WTqjgwHlXbSFevF32_DJVw
# 3  yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg  ikCg8xy5JIg_NGPx-MSIDA
# 4  11a8sVPMUFtaC7_ABRkmtw  ssoyf2_x0EQMed6fgHeMyQ  b1b1eb3uo-w561D0ZfCEiQ
#
#    stars                 date  \
# 0    1.0  2013-05-07 04:34:36
# 1    5.0  2017-01-14 21:30:33
# 2    5.0  2016-11-09 20:09:03
# 3    5.0  2018-01-09 20:56:38
# 4    1.0  2018-01-30 23:07:38
#
#                                                 text  useful  funny  cool
# 0  Total bill for this horrible service? Over $8G...       6      1     0
# 1  I *adore* Travis at the Hard Rock's new Kelly ...       0      0     0
# 2  I have to say that this office really has it t...       3      0     0
# ...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6685900 entries, 0 to 6685899
# Data columns (total 9 columns):
# review_id      object
# user_id        object
# business_id    object
# stars          float64
# date           object
# text           object
# useful         int64
# funny          int64
# cool           int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 459.1+ MB

# %%
review['text length'] = review['text'].apply(len)
review.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e1de253c6b06> in <module>()
# ----> 1 review['text length'] = review['text'].apply(len)
#       2 review.head()
#
# /Users/parvathy/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'float' has no len()

# %%
review.describe()
# Out:
#               stars        useful         funny          cool
# count  6.685900e+06  6.685900e+06  6.685900e+06  6.685900e+06
# mean   3.716199e+00  1.354134e+00  4.827667e-01  5.787708e-01
# std    1.463643e+00  3.700192e+00  2.378646e+00  2.359024e+00
# min    1.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00
# 25%    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    5.000000e+00  2.000000e+00  0.000000e+00  1.000000e+00
# max    5.000000e+00  1.241000e+03  1.290000e+03  5.060000e+02

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6685900 entries, 0 to 6685899
# Data columns (total 9 columns):
# review_id      object
# user_id        object
# business_id    object
# stars          float64
# date           object
# text           object
# useful         int64
# funny          int64
# cool           int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 459.1+ MB

# %%
yelp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3001e456b88c> in <module>()
# ----> 1 yelp.head()
#
# NameError: name 'yelp' is not defined

# %%
review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
# 2  2TzJjDVDEuAW6MR5Vuc1ug  n6-Gk65cPZL6Uz8qRm3NYw  WTqjgwHlXbSFevF32_DJVw
# 3  yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg  ikCg8xy5JIg_NGPx-MSIDA
# 4  11a8sVPMUFtaC7_ABRkmtw  ssoyf2_x0EQMed6fgHeMyQ  b1b1eb3uo-w561D0ZfCEiQ
#
#    stars                 date  \
# 0    1.0  2013-05-07 04:34:36
# 1    5.0  2017-01-14 21:30:33
# 2    5.0  2016-11-09 20:09:03
# 3    5.0  2018-01-09 20:56:38
# 4    1.0  2018-01-30 23:07:38
#
#                                                 text  useful  funny  cool
# 0  Total bill for this horrible service? Over $8G...       6      1     0
# 1  I *adore* Travis at the Hard Rock's new Kelly ...       0      0     0
# 2  I have to say that this office really has it t...       3      0     0
# ...

# %%
review.text
# Out:
# 0          Total bill for this horrible service? Over $8G...
# 1          I *adore* Travis at the Hard Rock's new Kelly ...
# 2          I have to say that this office really has it t...
# 3          Went in for a lunch. Steak sandwich was delici...
# 4          Today was my second out of three sessions I ha...
# 5          I'll be the first to admit that I was not exci...
# 6          Tracy dessert had a big name in Hong Kong and ...
# 7          This place has gone down hill.  Clearly they h...
# 8          I was really looking forward to visiting after...
# 9          It's a giant Best Buy with 66 registers.  I do...
# 10         Like walking back in time, every Saturday morn...
# 11         Walked in around 4 on a Friday afternoon, we s...
# 12         Wow. So surprised at the one and two star revi...
# 13         Michael from Red Carpet VIP is amazing ! I rea...
# 14         I cannot believe how things have changed in 3 ...
# ...

# %%
review[0].text.len
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-5a14d0755cb7> in <module>()
# ----> 1 review[0].text.len
#
# /Users/parvathy/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /Users/parvathy/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /Users/parvathy/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
review.text.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-91bec7f95e05> in <module>()
# ----> 1 review.text.len
#
# /Users/parvathy/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'len'

# %%
review['text length'] = review['text'].apply(len)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/parvathy/anaconda2/lib/python2.7/site-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/parvathy/anaconda2/lib/python2.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/parvathy/anaconda2/lib/python2.7/site-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/parvathy/anaconda2/lib/python2.7/inspect.py", line 1051, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/Users/parvathy/anaconda2/lib/python2.7/inspect.py", line 1011, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
# ...

# %%
review.dtypes
# Out:
# review_id       object
# user_id         object
# business_id     object
# stars          float64
# date            object
# text            object
# useful           int64
# funny            int64
# cool             int64
# dtype: object

# %%
review.text.isInstance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-4bee2191ca1b> in <module>()
# ----> 1 review.text.isInstance()
#
# /Users/parvathy/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'isInstance'

# %%
review.get(0).text.isInstance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-4254fc4bc52e> in <module>()
# ----> 1 review.get(0).text.isInstance()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
review.isna()
# Out:
#          review_id  user_id  business_id  stars   date   text  useful  funny  \
# 0            False    False        False  False  False  False   False  False
# 1            False    False        False  False  False  False   False  False
# 2            False    False        False  False  False  False   False  False
# 3            False    False        False  False  False  False   False  False
# 4            False    False        False  False  False  False   False  False
# 5            False    False        False  False  False  False   False  False
# 6            False    False        False  False  False  False   False  False
# 7            False    False        False  False  False  False   False  False
# 8            False    False        False  False  False  False   False  False
# 9            False    False        False  False  False  False   False  False
# 10           False    False        False  False  False  False   False  False
# ...

# %%
yelp['text length'] - yelp['text'].apply(len)
yelp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1916434af0da> in <module>()
# ----> 1 yelp['text length'] - yelp['text'].apply(len)
#       2 yelp.head()
#
# NameError: name 'yelp' is not defined

# %%
review['text length'] = review['text'].apply(len)
review.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e1de253c6b06> in <module>()
# ----> 1 review['text length'] = review['text'].apply(len)
#       2 review.head()
#
# NameError: name 'review' is not defined
